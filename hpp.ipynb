# %%
import sys

print(sys.executable)

import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

print("AIML Environment")
# Out:
# D:\AIML\ec\.venv\Scripts\python.exe
# AIML Environment
